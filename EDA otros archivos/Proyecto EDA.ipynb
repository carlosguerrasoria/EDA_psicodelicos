# %% [markdown]
# ![EDA.png](attachment:EDA.png)

# %% [markdown]
# # Proyecto Data Analysis
# ## Data Science Bootcamp
# En este proyecto vas a aplicar todo lo aprendido en el Ramp Up y el módulo de Data Analysis del bootcamp. Tendrás que realizar un análisis exploratorio de datos y presentar los resultados. Ten en cuenta lo siguiente:
#
# * **Miembros**: El proyecto es individual
# * **Datos**: Tienes que conseguir los datos por tu cuenta (ver abajo)
# * **Fechas**: Consultar calendario de Google Classroom
#
#
# ## Objetivo
# Lo que queremos mediante este tipo de análisis es resolver un problema real apoyándonos en datos, por lo que tendrás que plantearte primero qué es lo que quieres resolver, y a partir de ahí ir trabajando con los datos para acabar llegando a una conclusión. Plantea tus hipótesis antes de realizar el análisis exploratorio y después verifica si se han cumplido, o si has descubierto mediante los datos que lo que ocurría era justamente lo opuesto a lo que pensabas.
#
#
# ## Evaluación
# * **Presentación** (60%) no más de 10 minutos donde expondrás tu caso (ver apartado Presentación)
# * **Memoria** (20%) de no más de 10 páginas donde explicarás qué es lo que has hecho (ver apartado Memoria)
# * **Código** (10%) hay que entregar todo el código desarrollado. También se tiene en cuenta (tipo solución, limpieza, documentar...)
# * **Subir el proyecto a tu GitHub personal**. (10%) Este gran esfuerzo tiene que ser compartido, y te recomiendo que te crees un repositorio en GitHub para ir añadiendo tus proyectos personales. En caso de que el proyecto se componga de datos sensibles o no se quiera publicar, se puede mantener en repositorio privado (consultar profesores).
#
#
# ## Entregable
# Consistirá en un .zip que habrá que subir a Google Classroom. En el zip debe constar:
# * Presentación
# * Memoria
# * Código
# * Documentación utilizada
# * Archivo .txt con el enlace al repositorio de GitHub.
#
# El codigo deberá seguir la siguiente estructura de carpetas:
# 1. src/: aquí irá todo el código
# 2. src/data: todos los archivos de datos utilizados en el analisis. No subir a GitHub archivos demasiado pesados.
# 3. src/notebooks: los notebooks usados para pruebas.
# 4. src/utils: todos los modulos y funciones auxiliares creados para el desarrollo del proyecto.
# 5. src/main.ipynb: en este notebook tendrás que resumir todos los pasos de la analítica. También sería válido un script de Python (extensión .py).
#
# **GitHub**: hay que crear un README con una descripción de tu proyecto. Breve. El objetivo de este README es enterarse de forma rápida de qué va tu proyecto y qué tecnologías has utilizado para llevarlo a cabo, no es más que un escaparate de tu trabajo. Hay que ir documentando bien los trabajos para acabar el bootcamp con un buen portfolio. En [este enlace](https://github.com/alexhuang1117/Data-Science-Portfolio) tienes un ejemplo de cómo tener documentados los proyectos en tu GitHub. Encontrarás en el notebook de markdown todo lo que necesitas para crear un README decente.

# %% [markdown]
# ## Presentación
# https://www.data-to-viz.com/
# Puesto que en la vida real la mayoría de presentaciones se realizan a un público no técnico, ésta no va a ser menos. Si tienes que explicar algo técnico, cuéntalo, pero para alguien que no sabe lo que significa. Por ejemplo, ¿cómo contarías qué es una matriz de correlación? No queremos ver código, ni cómo estructuraste el proyecto en carpetas, ni cómo de difícil ha sido limpiarlo. Al cliente/tu jefe le da igual :). Explicar cosas técnicas lleva tiempo por lo que piensa muy bien en lo que vas a decir y en cómo lo sintetizarás.
#
# Tendrás que exponer bien tu caso de uso (30% del tiempo), explicar qué es lo que has hecho para resolverlo (50%), y acabar la presentación con unas conclusiones y oportunidades que nos brinda el proyecto (20%), para cerrar el plantemiento inicial del caso de uso. Los % son orientativos...
#
# **¿Formatos de la presentación?** Nada de Notebooks, ni informes en pdf o HTML. Formato presentación en PowerPoint, Prezi o la plataforma que mejor conozcas, siendo perfectamente combinable con un dashboard desarrollado mediante alguna de las herramientas aprendidas durante el curso (Powr BI, Streamlit, Plotly).
#
# **Consejos**: Si usas un PowerPoint... será tu apoyo a la hora de presentar, aquí el protagonista es tu discurso. Por favor, que la presentación no sea un conjunto de puntos inconexos. Intenta llevar un hilo, como si de una historia se tratase. Véndete, destaca las fortalezas de tu trabajo sobre las debilidades. Interactúa con el público. Si vas a contar algo de negocio, ¿puedes traducirlo a números? ¿Qué impacto tendrá tu analítica?. Muestra algunos datos concretos (estadísticos simples) para justificar tu business case o para cerrar tu presentación. Si has elegido una temática que está acorde con tus gustos/background, aprovecha al principio para contarlo y empatizar mucho más con el público. Si vas a hacer una demo, grábala por si te falla algo en la presentación (conexión a Internet). Prepárate las respuestas a algunas posibles preguntas en un anexo de la presentación.
#
# **NOTA**: existen muchas plantillas gratuitas en la web para hacer presentaciones. [Aquí tienes unas cuantas](https://www.free-powerpoint-templates-design.com/free-powerpoint-templates-design/).
#
# ## Memoria
# Simplemente es un documento que complemente a la presentación. Nada serio. Ya que en la presentación no se va a ver reflejado todo el esfuerzo dedicado al proyecto, utiliza este documento para describir todo tu trabajo, qué técnicas has utilizado, con qué dificultades te has encontrado. No más de 5 hojas. Recuerda documentar bien las fuentes de datos utilizadas en la memoria.
#
#
# ## Pasos del proyecto
#
# 1. Elegir temática
#     1. **Elegir una temática y buscar datos en función de la misma**. Es algo más complejo que la segunda opción ya que puede ocurrir que no encuentres datos que te sirvan para tu propósito, o que tengas que conseguirlos mediante APIs, scrapping, descarga de BBDD.... No obstante, esta opción es la que más se asemejaría a un caso real, ya que una gran problemática en este tipo de proyectos es encontrar datos.
#
#     2. **Directamente ir a páginas de datos abiertos y escoger un dataset de tu interés**. Si no tienes clara la temática puedes buscar en alguno de los enlaces de datos (recomendable Kaggle) y escoger un tema que te motive.
#
# 2. Obtención de datos. ¿Puedes llevar a cabo el proyecto con estos datos?
# 3. Define tu hipótesis. ¿Qué piensas que puedes obtener de estos datos? ¿Qué vas a poder resolver? ¿Cómo lo vas a llevar a cabo?
# 4. Preprocesado: obtén todos los datos de las diferentes fuentes que hayas utilizado, juntalos y ponlos en un formato entendible.
# 5. Limpia los datos: duplicados, missings, columnas inútiles...
# 6. Exploratorio: obtén todos los estadísticos y gráficos que necesites para entender bien tu dataset.
# 7. Concluye con tu análisis si estabas o no en lo cierto acerca de tu planteamiento y tu hipótesis.
# 8. (Bonus track). Crea un dashboard para representar tu análisis exploratorio.
# 9. Documenta tu proyecto y súbelo a GitHub.
#
#
# **Consideraciones a la hora de elegir tema**: después del proyecto de Data Analysis, hay que realizar el de Machine Learning, y Data Science & Business. Intenta escoger un dataset que te pueda servir después para realizar predicciones sobre alguna de tus variables de interés. Este punto no es obligatorio, pero si recomendable.

# %% [markdown]
# ## Datos
# ¿De dónde saco los datos? Posibles fuentes:
# - [API de Spotify] https://developer.spotify.com/documentation/web-api
# - [API de Marvel] https://developer.marvel.com
# - [API de AEMET]
# - [API de Idealista](https://www.idealista.com/labs/)
# - [API de Booking](https://developers.booking.com/api/index.html)
# - [API de Tripadvisor](http://developer-tripadvisor.com/content-api/)
# - [API de Facebook](https://developers.facebook.com/docs/apis-and-sdks?locale=es_ES)
# - [API de Twitter](https://developer.twitter.com/en/docs)
# - [API de Instagram](https://www.instagram.com/developer/)
# - [APIs de Google Maps](https://cloud.google.com/maps-platform?hl=es)
# - [Google Timeline](https://www.google.es/maps/timeline?pb). Todo tu registro de actividad de Google, como los lugares que has visitado
#
# - [Alexa. Tráfico de webs](https://www.alexa.com/siteinfo)
# - [Catastro](https://ovc.catastro.meh.es/ovcservweb/OVCSWLocalizacionRC/OVCCoordenadas.asmx)
# - [Airbnb](http://insideairbnb.com/index.html)
# - Web scrapping. Acceso automatizado a cualquier web.
# - Kaggle: página con competiciones de data scientists. Muchísimos datasets.
# - QPython 3L: APP para ejecutar código Python en el movil. Podrás sacar datos de tu actividad con el teléfono (horarios, geoposicionamiento)
# - Coronavirus. Se están empezando a librerar muchísimos datasets con datos del coronavirus en todo el mundo. En Kaggle hay varios.
# - [Web de datos abiertos del gobierno](https://datos.gob.es/)
# - [OpenStreetMap](https://wiki.openstreetmap.org/wiki/API). Datos de ubicaciones (como Google Maps) abiertos
# - [Obtención de datos bursátiles](https://financetrain.com/best-python-librariespackages-finance-financial-data-scientists/)
# - [ESRI Datos abiertos España](https://opendata.esri.es/)
# - [INE](https://www.ine.es/nomen2/ficheros.do)
# - [Red.es](https://www.red.es/redes/es/que-hacemos/datos-abiertos)
# - [Datos abiertos gobierno](https://www.hacienda.gob.es/es-ES/GobiernoAbierto/Datos%20Abiertos/Paginas/Catalogodedatosabiertos.aspx)
# - [Ayuntamiento de Madrid](https://datos.madrid.es/portal/site/egob/)
# - [Ayuntamiento de Barcelona](https://opendata-ajuntament.barcelona.cat/es)
# - [Metro de Madrid](https://data-crtm.opendata.arcgis.com/)
# - [Portal datos europeo I](https://data.europa.eu/euodp/es/home)
# - [Portal datos europeo II](https://www.europeandataportal.eu/data/datasets?locale=en&minScoring=0)
# - [Google Dataset Search](https://datasetsearch.research.google.com/)
# - [Indicadores macro mundiales](https://databank.worldbank.org/home)
# - [Indicadores macro mundiales](https://ilostat.ilo.org/data/country-profiles/)
# - [Amplio repositorio de Datasets](https://datacommons.org/)
# - [Datos macro mundiales](https://www.gapminder.org/data/)
# - [GitHub con gran cantidad de APIs públicas](https://github.com/public-apis/public-apis)
# - [Datos sobre migraciónn](https://migrationdataportal.org/es/node/2955)
# - [Web de datos abiertos de España](https://www.epdata.es/)
# - [Redapi: Plataforma de APIs con amplia capa gratuita](https://rapidapi.com/blog/most-popular-api/)
# - [Artículo para trabajar con histórico de bolsa](https://towardsdatascience.com/how-to-get-stock-data-using-python-c0de1df17e75)
# - [Otro gran repo de datasets](https://www.paperswithcode.com/datasets)
#
#
# Si tienes algún tema sobre el que quieras investigar, y no encaja con ninguno de los enlaces propuestos, consúltalo con los profesores para investigar de dónde podríamos sacar datos para ese análisis.

# %% [markdown]
# # Estudio sobre consumo de sustancias psicodélicas
#
# - Muestra: 1021 personas
# - Residencia: Europa (63%), América del sur (30%), América del norte (5%), África (2%), Asia (1,9%), Oceanía (0,09%)
# - Rango edad: 18-79
# - Rango ingresos: 5000$-100000$
# - Sexo: 52% hombres, 48%- mujeres
# - Entorno: urbano (79%) y residencial (21%)
# - Nivel educativo: Grado universitario(68%), Educ. Primaria (30%), Postgrado (0.6%)
# - Consumidores de psicodélicos: Sí (73%), No (27%)

# %% [markdown]
# ## Parte 1: Contraste de hipótesis
#
# <b>Hipótesis 1:</b> Hay determinados psicodélicos que se asocian a motivaciones de consumo (sustancias_consumidas --> motivacion_princ)
#
# <b>Hipótesis 2:</b> Hay determinados psicodélicos que se asocian a lugares de consumo (sustancias_consumidas --> donde_consume)
#
# <b>Hipótesis 3:</b> Hay determinados psicodélicos que se asocian a acompañantes (sustancias_consumidas --> con_quien_consume)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_info_columns', 200)

# %%
df = pd.read_excel("./1000sujetos.xlsx")

# %%
df.tail(3)
# Out:
#       edad    sexo    estatus residencia entorno_res            empleo  \
# 1019    35  Hombre   Casado/a     Europa      Urbano  Jornada completa
# 1020    35  Hombre   Casado/a     Europa      Urbano  Jornada completa
# 1021    34   Mujer  Soltero/a     Europa      Urbano        Estudiante
#
#                     nivel_edu       ingresos ha_consumido  \
# 1019  Educación universitaria  30,000-40,000           No
# 1020  Educación universitaria  30,000-40,000           No
# 1021  Educación universitaria       0-10,000           Sí
#
#                                   sustancias_consumidas consumo_estimado  \
# 1019                                            Ninguna                0
# 1020                                            Ninguna                0
# 1021  LSD (ácido, tripi), Psilocibina (setas o trufa...               17
#
#                ultimo_consumo     t_1-ultimo_cons             frec_anual  \
# 1019       Nunca he consumido  Nunca he consumido                  Nunca
# ...

# %%
#Elimino las columnas a partir de la 40, no me interesan para este EDA.
columns_to_drop = df.columns[39: ]
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1022 entries, 0 to 1021
# Data columns (total 39 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   edad                       1022 non-null   int64
#  1   sexo                       1022 non-null   object
#  2   estatus                    1022 non-null   object
#  3   residencia                 1022 non-null   object
#  4   entorno_res                1022 non-null   object
#  5   empleo                     1022 non-null   object
#  6   nivel_edu                  1022 non-null   object
#  7   ingresos                   1022 non-null   object
#  8   ha_consumido               1022 non-null   object
#  9   sustancias_consumidas      1022 non-null   object
#  10  consumo_estimado           1022 non-null   object
#  11  ultimo_consumo             1022 non-null   object
#  12  t_1-ultimo_cons            1022 non-null   object
# ...

# %% [markdown]
# ## Columna sustancias_consumidas

# %%
# Creamos una nueva columna con la sustancia principal consumida de cada encuestado, y lo dejamos en unas pocas categorías
categorias_sustancias = df.sustancias_consumidas.to_list()

# Obtener la primera palabra de cada string
primeras_palabras = [frase.split(',')[0].split()[0] for frase in categorias_sustancias]
df['sustancias_consumidas_princ'] = primeras_palabras

#Asignamos valores sueltos a ciertas categorías
thc = ['THC', 'porros', 'MARIHUANA', 'marihuana', 'Marihuana']
hongos = ['Hongos', 'PSILOCIBINA','Cucumelos']
ayahuasca = 'Ayahuasca'
otras = ['varias', 'Escopolamina', 'Metilfenidato','Escopolamina', 'Cocaina', 'Varias']

df['sustancias_consumidas_princ'] = df['sustancias_consumidas_princ'].replace(thc, 'Marihuana')
df['sustancias_consumidas_princ'] = df['sustancias_consumidas_princ'].replace(hongos, 'Psilocibina')
df['sustancias_consumidas_princ'] = df['sustancias_consumidas_princ'].replace(ayahuasca, 'DMT')
df['sustancias_consumidas_princ'] = df['sustancias_consumidas_princ'].replace(otras, 'Otras')

#Value counts
df['sustancias_consumidas_princ'].value_counts()
# Out:
# sustancias_consumidas_princ
# LSD            506
# Ninguna        273
# Psilocibina    147
# Mescalina       45
# MDMA            24
# DMT             16
# Marihuana        7
# Otras            4
# Name: count, dtype: int64

# %% [markdown]
# ## Columna motivacion

# %%
# Creamos una nueva columna con la motivación principal de cada encuestado, y lo dejamos en unas pocas categorías
df['motivacion_princ'] = df['motivacion']

df['motivacion_princ'] = df['motivacion_princ'].apply(lambda x: 'Diversión' if str(x).startswith('Para divertirme') else x)
df['motivacion_princ'] = df['motivacion_princ'].apply(lambda x: 'Autoconocimiento' if str(x).startswith('Para conocerme') else x)
df['motivacion_princ'] = df['motivacion_princ'].apply(lambda x: 'Terapéutico' if str(x).startswith('Con fines terapéuticos') else x)
df['motivacion_princ'] = df['motivacion_princ'].apply(lambda x: 'Espiritual' if str(x).startswith('Con fines religiosos') else x)

motivaciones_permitidas = ['Diversión', 'Autoconocimiento', 'Terapéutico', 'Espiritual', 'No he consumido']
df['motivacion_princ'] = df['motivacion_princ'].where(df['motivacion_princ'].isin(motivaciones_permitidas), other='Otros')

#Value counts
df['motivacion_princ'].value_counts()
# Out:
# motivacion_princ
# Diversión           460
# No he consumido     272
# Autoconocimiento    204
# Terapéutico          40
# Otros                34
# Espiritual           12
# Name: count, dtype: int64

# %% [markdown]
# ## Columna donde_consume

# %%
# Creamos una nueva columna con el lugar de consumo principal de cada encuestado, y lo dejamos en unas pocas categorías

df['donde_consume_princ'] = df['donde_consume']
df['donde_consume_princ'] = df['donde_consume_princ'].apply(lambda x: 'Casa' if str(x).startswith('En casa') else x)
df['donde_consume_princ'] = df['donde_consume_princ'].apply(lambda x: 'Naturaleza' if str(x).startswith('En la naturaleza') else x)
df['donde_consume_princ'] = df['donde_consume_princ'].apply(lambda x: 'Fiestas' if str(x).startswith('En fiestas') else x)
df['donde_consume_princ'] = df['donde_consume_princ'].apply(lambda x: 'Calle' if str(x).startswith('En la calle') else x)

donde_permitidos = ['Casa', 'Naturaleza', 'Fiestas', 'Calle', 'No he consumido']
df['donde_consume_princ'] = df['donde_consume_princ'].where(df['donde_consume_princ'].isin(lugares_permitidos), other='Otros')

df.donde_consume_princ.value_counts()
# Out:
# donde_consume_princ
# Casa               526
# No he consumido    275
# Naturaleza         155
# Fiestas             38
# Otros               17
# Calle               11
# Name: count, dtype: int64

# %% [markdown]
# ## Columna con_quien_consume

# %%
# Creamos una nueva columna con la compañía principal de cada encuestado, y lo dejamos en unas pocas categorías
df['con_quien_consume_princ'] = df['con_quien_consume']
df['con_quien_consume_princ'] = df['con_quien_consume_princ'].apply(lambda x: 'Amigos' if str(x).startswith('Amigos') else x)
df['con_quien_consume_princ'] = df['con_quien_consume_princ'].apply(lambda x: 'Chamán' if str(x).startswith('Chamán') else x)
df['con_quien_consume_princ'] = df['con_quien_consume_princ'].apply(lambda x: 'Terapeuta' if str(x).startswith('Terapeuta') else x)
df['con_quien_consume_princ'] = df['con_quien_consume_princ'].apply(lambda x: 'Pareja o familia' if str(x).startswith('Pareja') else x)
df['con_quien_consume_princ'] = df['con_quien_consume_princ'].apply(lambda x: 'Pareja o familia' if str(x).startswith('Familiares') else x)
df['con_quien_consume_princ'] = df['con_quien_consume_princ'].apply(lambda x: 'No he consumido' if str(x).startswith('No he consumido') else x)

con_quien_permitidos = ['Amigos', 'Chamán', 'Terapeuta','Pareja o familia', 'Solo', 'No he consumido']
df['con_quien_consume_princ'] = df['con_quien_consume_princ'].where(df['con_quien_consume_princ'].isin(con_quien_permitidos), other='Otros')


df.con_quien_consume_princ.value_counts()
# Out:
# con_quien_consume_princ
# Amigos              471
# No he consumido     277
# Chamán              128
# Solo                 52
# Terapeuta            44
# Pareja o familia     40
# Otros                10
# Name: count, dtype: int64

# %%
#Convertimos la columna 'ingresos' en numérica para poder operar con ella

#Pasar todos los strings a números, salvo los 'No sabe/No contesta'
df.loc[df['ingresos'] == '0-10,000', 'ingresos'] = 5000
df.loc[df['ingresos'] == '10,000-20,000', 'ingresos'] = 15000
df.loc[df['ingresos'] == '20,000-30,000', 'ingresos'] = 25000
df.loc[df['ingresos'] == '30,000-40,000', 'ingresos'] = 35000
df.loc[df['ingresos'] == '40,000-50,000', 'ingresos'] = 45000
df.loc[df['ingresos'] == '50,000-60,000', 'ingresos'] = 55000
df.loc[df['ingresos'] == '60,000-70,000', 'ingresos'] = 65000
df.loc[df['ingresos'] == '70,000-80,000', 'ingresos'] = 75000
df.loc[df['ingresos'] == '80,000-90,000', 'ingresos'] = 85000
df.loc[df['ingresos'] == '90,000-100,000', 'ingresos'] = 95000
df.loc[df['ingresos'] == '100,000 ó más', 'ingresos'] = 100000

#Pasar la columna a int64
df['ingresos'] = pd.to_numeric(df['ingresos'], errors='coerce')

#Pasar los NaN a la mediana de los valores la columna
mediana = df['ingresos'].median()
df['ingresos'] = df['ingresos'].fillna(mediana)

#Pasamos la columna 'ingresos' a tipo numérica
df['ingresos'] = df['ingresos'].astype('int64')

#Value counts
df['ingresos'].value_counts()
# Out:
# ingresos
# 15000     455
# 5000      186
# 25000     142
# 35000      84
# 45000      45
# 55000      33
# 100000     25
# 65000      24
# 95000      10
# 85000       9
# 75000       9
# Name: count, dtype: int64

# %%
#Renombramos la columna 'estatus' a 'estado civil' y lo reducimos a solo 4 categorías
df.rename(columns={'estatus': 'Estado_civil'}, inplace=True)

soltero = ['Soltero/a',
           'No tengo carga']

pareja = ['En pareja',
             'Casado/a',
             'En pareja con hijos anteriores ',
             'Relación no conviviente',
             'Casade pero en relaciones poliamorosas',
             'Pareja no conviviente',
             'Poliamor']

separado_divorciado = ['Divorciado/a',
                       'Separado',
                       'Distanciado',
                       'Separada',
                       'Separada sin casarse con hijo',
                       'Madre monoparental']

viudo = ['Viudo/a']

df['Estado_civil'] = df['Estado_civil'].replace(soltero, 'Soltero/a')
df['Estado_civil'] = df['Estado_civil'].replace(pareja, 'En pareja')
df['Estado_civil'] = df['Estado_civil'].replace(separado_divorciado, 'Separado/a o divorciado/a')
df['Estado_civil'] = df['Estado_civil'].replace(viudo, 'Viudo/a')

#Value counts
df.Estado_civil.value_counts()
# Out:
# Estado_civil
# En pareja                    487
# Soltero/a                    429
# Separado/a o divorciado/a     95
# Viudo/a                       11
# Name: count, dtype: int64

# %%
#Convertimos la columna 'consumo_estimado' a numérica
df['consumo_estimado'].unique()
df['consumo_estimado'] = df['consumo_estimado'].apply(lambda x: '100' if str(x).startswith('Más') else x)
df['consumo_estimado'] = df['consumo_estimado'].astype('int64')

# %%
def cardinalidad(df_in, umbral_categorica, umbral_continua):
    # DataFrame para almacenar los resultados
    resultados = pd.DataFrame(columns=['Cardinalidad', '%_card', 'Clasificacion'])
    
    # Número total de filas en el DataFrame
    num_filas = len(df_in)
    
    for col in df_in.columns:
        # Calcular la cardinalidad
        cardinalidad = df_in[col].nunique()
        
        # Calcular el porcentaje de valores diferentes
        porcentaje = cardinalidad / num_filas * 100
        
        # Determinar la clasificación de la columna
        if cardinalidad == 2:
            clasificacion = 'Binaria'
        elif cardinalidad < umbral_categorica:
            clasificacion = 'Categórica'
        else: 
            if porcentaje == 100:
                clasificacion = 'Indice'
            elif porcentaje >= umbral_continua:
                clasificacion = 'Numérica Continua'
            else:
                clasificacion = 'Numérica Discreta'
        
        # Añadir los resultados al DataFrame
        resultados.loc[col] = [cardinalidad, porcentaje, clasificacion]
    
    return resultados

cardinalidad(df, 10, 30)
# Out:
#                              Cardinalidad     %_card      Clasificacion
# edad                                   58   5.675147  Numérica Discreta
# sexo                                    2   0.195695            Binaria
# Estado_civil                            4   0.391389         Categórica
# residencia                              6   0.587084         Categórica
# entorno_res                             2   0.195695            Binaria
# empleo                                 63   6.164384  Numérica Discreta
# nivel_edu                              56   5.479452  Numérica Discreta
# ingresos                               11   1.076321  Numérica Discreta
# ha_consumido                            2   0.195695            Binaria
# sustancias_consumidas                 163  15.949119  Numérica Discreta
# consumo_estimado                       53   5.185910  Numérica Discreta
# ultimo_consumo                         11   1.076321  Numérica Discreta
# ...

# %%
pinta_distribucion_categoricas(df, ['sustancias_consumidas_princ','motivacion_princ'], mostrar_valores=True)

# %%
plot_categorical_relationship_fin (df, 'motivacion_princ', 'sustancias_consumidas_princ', relative_freq=False, show_values=True, size_group = 5)

# %%
df.groupby('motivacion_princ', as_index = False)['sustancias_consumidas_princ'].value_counts(normalize = True)
# Out:
#     motivacion_princ sustancias_consumidas_princ  proportion
# 0   Autoconocimiento                         LSD    0.578431
# 1   Autoconocimiento                 Psilocibina    0.274510
# 2   Autoconocimiento                   Mescalina    0.112745
# 3   Autoconocimiento                         DMT    0.029412
# 4   Autoconocimiento                       Otras    0.004902
# 5          Diversión                         LSD    0.758696
# 6          Diversión                 Psilocibina    0.145652
# 7          Diversión                        MDMA    0.047826
# 8          Diversión                   Mescalina    0.028261
# 9          Diversión                   Marihuana    0.010870
# 10         Diversión                       Otras    0.004348
# 11         Diversión                         DMT    0.002174
# 12         Diversión                     Ninguna    0.002174
# 13        Espiritual                 Psilocibina    0.416667
# ...

# %%
tabla_contingencia = pd.crosstab(df['motivacion_princ'], df['sustancias_consumidas_princ'])
tabla_contingencia
# Out:
# sustancias_consumidas_princ  DMT  LSD  MDMA  Marihuana  Mescalina  Ninguna  \
# motivacion_princ
# Autoconocimiento               6  118     0          0         23        0
# Diversión                      1  349    22          5         13        1
# Espiritual                     2    4     0          0          0        1
# No he consumido                0    1     1          0          1      268
# Otros                          3   18     1          2          2        2
# Terapéutico                    4   16     0          0          6        1
#
# sustancias_consumidas_princ  Otras  Psilocibina
# motivacion_princ
# Autoconocimiento                 1           56
# Diversión                        2           67
# Espiritual                       0            5
# No he consumido                  1            0
# Otros                            0            6
# Terapéutico                      0           13

# %%
from scipy.stats import chi2_contingency

chi2, p, dof, expected = chi2_contingency(tabla_contingencia)

print("Valor Chi-Cuadrado:", chi2)
print("P-Value:", p)
print("Grados de Libertad:", dof)
print("Tabla de Frecuencias Esperadas:\n", expected)
# Out:
# Valor Chi-Cuadrado: 1142.1903642440293
# P-Value: 3.485475009763754e-217
# Grados de Libertad: 35
# Tabla de Frecuencias Esperadas:
#  [[3.19373777e+00 1.01001957e+02 4.79060665e+00 1.39726027e+00
#   8.98238748e+00 5.44931507e+01 7.98434442e-01 2.93424658e+01]
#  [7.20156556e+00 2.27749511e+02 1.08023483e+01 3.15068493e+00
#   2.02544031e+01 1.22876712e+02 1.80039139e+00 6.61643836e+01]
#  [1.87866928e-01 5.94129159e+00 2.81800391e-01 8.21917808e-02
#   5.28375734e-01 3.20547945e+00 4.69667319e-02 1.72602740e+00]
#  [4.25831703e+00 1.34669276e+02 6.38747554e+00 1.86301370e+00
#   1.19765166e+01 7.26575342e+01 1.06457926e+00 3.91232877e+01]
#  [5.32289628e-01 1.68336595e+01 7.98434442e-01 2.32876712e-01
#   1.49706458e+00 9.08219178e+00 1.33072407e-01 4.89041096e+00]
#  [6.26223092e-01 1.98043053e+01 9.39334638e-01 2.73972603e-01
#   1.76125245e+00 1.06849315e+01 1.56555773e-01 5.75342466e+00]]

# %%
df.to_csv('1000sujetos.csv', index=False)

# %%
#Grafico de dispesión plt.scatter()
x = df['edad']
plt.xlabel("edad")
y = df['ingresos'] 
plt.ylabel("ingresos")
consumo = df['consumo_estimado']

plt.title("Edad/ingresos vs consumo")

plt.scatter(x, y, s=consumo, c=consumo,alpha=0.3,
            cmap='viridis');
plt.colorbar();

# %%
df.sustancias_consumidas_princ.value_counts()
# Out:
# sustancias_consumidas_princ
# LSD            506
# Ninguna        273
# Psilocibina    147
# Mescalina       45
# MDMA            24
# DMT             16
# Marihuana        7
# Otras            4
# Name: count, dtype: int64

# %%
corr_matrix = df.corr(numeric_only= True) # Si no lo pones y tienes variables tipo texto, fallará7
corr_matrix

plt.figure(figsize=(10, 8))  # Ya lo veremos pero esto permite ajustar el tamaño de las gráficas
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", 
            cbar=True, square=True, linewidths=.5) # el cmap es el rango de colores usado para representar "el calor"

plt.title('Matriz de Correlación')
plt.xticks(rotation=45)  # Rota las etiquetas de las x si es necesario
plt.yticks(rotation=45)  # Rota las etiquetas de las y si es necesario

plt.show()
plt.show()

# %%
sns.catplot(x = "ingresos", y = "edad", hue = "sustancias_consumidas_princ", data = df, kind = "swarm", height=16);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/categorical.py:3399: UserWarning: 5.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
edad = df['edad']
ingresos = df["ingresos"]
sustancias = df["sustancias_consumidas_princ"]
consumo = df["consumo_estimado"]
kwargs = dict(alpha=0.5)

plt.figure(figsize=(15,10))
sns.set_theme(style="ticks", font_scale= 0.8)
sns.scatterplot(x=edad, y=ingresos, size=consumo, hue=sustancias, data=df, palette="viridis", sizes=(5,450),**kwargs);

# %%
fig,axs = plt.subplots(1,1,figsize= (10,6))
sns.histplot(df["ingresos"], #Ojo con /nnn mirar el valor que queremos mostrar
             kde=True, #Tipo
             color='c',
             bins=100, ax = axs) # Otra forma, sin recurrir al dataframe como argumento
axs.set_xlabel("Histograma + func densidad")
axs.set_xlabel("Ingresos")
axs.set_ylabel("Cuántos");

# %%
#

cuenta_ajena = ['Jornada completa',
                'Media jornada/tiempo parcial',
                'Jornada intensiva',
                'Media jornada + estudiante',
                'Media jornada',
                'Ventas',
                'Jornada completa/estudiante',
                'Estudio y trabajo',
                'Jornada completa/estudiante ',
                'Madre, Media jornada, estudiante, amo de casa ',
                'Media jornada + estudiante ',
                'Estudio y trabajo ']

amo_casa = ['Amo/a de casa',
            'amo de casa']

autonomo = ['Autónomo ',
            'Personal',
            'Emprendedora',
            'Autónomo',
            'Autonomo',
            'pequeña empresa',
            'Independiente',
            'Danzaterapeuta',
            'autonomo',
            'Terapeuta ',
            'Artista Lírico Solista ',
            'Autónomo, sin horarios fijos',
            'Autónoma',
            'Trabajo por mi cuenta ',
            'Emprendedor',
            'free lance ',
            'Trabajo x mi cuenta, horario variado',
            'Freelance ',
            'Artista',
            'Comerciante ',
            'Autonoma, ',
            'Independiente',
            'Dr. Antropólogo',
            'Músico de handpan',
            'Por honorarios ',
            'Trabajos temporales ',
            'Conductor por destajo',
            'Empresa propia ',
            'Libre ejercicio de la profesión ',
            'Comerciante',
            'Turno 24x48',
            '3 trabajos por prestacion de servicios',
            'Empresario',
            'Terapeuta manejo mi propio horario',
            'Terciaria ',
            'Flexible independiente ',
            'Trabajo independiente ',
            'Facilitador de Ayahuasca',
            'Autonoma',
            'Teletrabajo, organizo mi tiempo.',
            'Freelance',
            'Temporero',
            'Temporada verano',
            'Temporera',
            'artista plástica',
            'pequeña empresa (te faltan varias opciones de empleos)',
            'Independiente ',
            'Arte',
            'Rentista']

estudiante = ['Estudiante',
              'Prácticas de máster',
              'estudiante']

pensionista = ['PENSIONISTA',
               'Pensionista',
               'pensionista']


df['empleo'] = df['empleo'].replace(cuenta_ajena, 'Cuenta ajena')
df['empleo'] = df['empleo'].replace(amo_casa, 'Amo/a casa')
df['empleo'] = df['empleo'].replace(autonomo, 'Autonomo')
df['empleo'] = df['empleo'].replace(estudiante, 'Estudiante')
df['empleo'] = df['empleo'].replace(pensionista, 'Pensionista')

df.empleo.unique()
# Out:
# array(['Estudiante', 'Cuenta ajena', 'Desempleado', 'Autonomo',
#        'No sabe/No contesta', 'Jubilado', 'Amo/a casa', 'Pensionista'],
#       dtype=object)

# %%
#Reducimos la columna 'nivel_edu civil' a solo 4 categorías

postgrado = ['Post grado',
             'maestría',
             'Pos Grando',
             'Master,edicación universitaria',
             'Doctor',
             'posgrado'
             'Master, edicación universitaria',
             'Master, edicación universitaria',
             'posgrado']

edu_sup = ['Educación universitaria',
           'terciaria: Magisterio (también te faltan opciones en ese ítem)',
           'Licenciado ','Terciaria','Terciario ',
           'Estudios de postgrado en pedagogía ',
           'Estudios Artísticos ']

edu_media = ['Grado medio ',
            'Ciclo formativo de grado superior ',
            'Ciclo Formativo de grado superior ',
            'Maestría',
            'FP',
            'Ciclo Formativo Grado Superior',
            'Preparatoria',
            'Grado superior',
            'Formación Profesional ',
            'Ciclo superior',
            'FP2','estudiando en la universidad ',
            'Técnico superior ',
            'Comercio',
            'estudiando tecnicatura ',
            'Profesional',
            'Técnico ',
            'Certificados de profesionalidad ',
            'Formación Profesional GS',
            'FP superior',
            'Grado superior ',
            'Formación Profesional Superior',
            'Psicoterapeuta ',
            'Formación profesional ',
            'Técnico superior F.P.',
            'Diseño de interiores',
            'Medio',
            'FpII',
            'Grado Superior',
            'Bachiller',
            'Fp',
            'Formación profesional superior']
           
edu_sec = ['Educación secundaria',
           'Medio superior Bachillerato ',
           'Bachillerato ',
           'Formación Profesional de Grado Superior',
           'Universidad incompleta ',
           'Bachiller Superior ',
           'EBAU ',
           'Grado Superior ']


df['nivel_edu'] = df['nivel_edu'].replace(postgrado, 'Postgrado')
df['nivel_edu'] = df['nivel_edu'].replace(edu_sup, 'Grado universitario')
df['nivel_edu'] = df['nivel_edu'].replace(edu_media, 'Educación secundaria')
df['nivel_edu'] = df['nivel_edu'].replace(edu_sec, 'Educación primaria')

df.nivel_edu.unique()
# Out:
# array(['Grado universitario', 'Educación primaria', 'No sabe/No contesta',
#        'Postgrado', 'Ninguno'], dtype=object)

# %%
#Creamos una nueva columna 'sustancias_consumidas_princ', y la situamos junto a su original 'sustancias_consumidas'

df["sustancias_consumidas_princ"] = df["sustancias_consumidas"]

col2 = df.pop("sustancias_consumidas_princ")

df.insert(10, "sustancias_consumidas_princ", col2)



#

lsd = ['LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), 2cb, ketamina',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis)',
       'LSD (ácido, tripi)',
       'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Salvia divinorum',
       'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Salvia divinorum',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Changa',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma)',
       'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis)',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis), Salvia divinorum',
       'LSD (ácido, tripi), MDMA (éxtasis)',
       'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis)',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), Salvia divinorum',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), Salvia divinorum',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), MDMA (éxtasis)',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis), Salvia divinorum',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético)',
       'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), Salvia divinorum',
       'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis)',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Ketamina',
       'LSD (ácido, tripi), DMT (ayahuasca, en cristales), MDMA (éxtasis), Ketamina, 2CB, 2CE',
       'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), 2cb',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis), Salvia divinorum',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Salvia divinorum',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis), Ibogaína (iboga)',
       'LSD (ácido, tripi), DMT (ayahuasca, en cristales), MDMA (éxtasis), Salvia divinorum',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis)',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis), Ibogaína (iboga), Salvia divinorum',
       'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas)',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), Salvia divinorum',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Changa, ',
       'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), MDA',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), MDMA (éxtasis)',
       'LSD (ácido, tripi), Marihuana',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas)',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), DMT (ayahuasca, en cristales)',
       'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis), Salvia divinorum, Al-lad, 1p-lsd, 1cp-lsd',
       'LSD (ácido, tripi), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis)',
       'LSD (ácido, tripi), DMT (ayahuasca, en cristales), MDMA (éxtasis)',
       'LSD (ácido, tripi), DMT (ayahuasca, en cristales)',
       'LSD (ácido, tripi), MDMA (éxtasis), "Changa" ayahuasca para fumar',
       'LSD (ácido, tripi), MDMA (éxtasis), Ketamina',
       'LSD (ácido, tripi), MDMA (éxtasis), Salvia divinorum, Mezcalina en pastilla (Inteligent)',
       'LSD (ácido, tripi), MDMA (éxtasis), Tusi, setas alucinógenas ',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis)',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), DMT (ayahuasca, en cristales), MDMA (éxtasis)',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), MDMA (éxtasis), Ketamina',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), 5 Meo-DMT (bufo alvarius/sapo, sintético), Salvia divinorum',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis), Salvia divinorum, Amanita muscaria, yopo, cannabis, ',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis)',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), Ketamina',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales)',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), Marihuana ',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Salvia divinorum, Cannabis',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Salvia divinorum, Cristal',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Salvia divinorum, Ketamina',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Salvia divinorum',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Speed cocaína éxtasis ',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Speed,cocaina,ketamina,marihuana',
       'LSD (ácido, tripi), Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Yopo del Amazonas ',
       'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis), Ketamina',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis)',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), Acido Sunshine',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), Cannabis ',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 4-HO-MET, 2C-B',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), 4-HO-MET 2C-B FLY',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), Ibogaína (iboga), Salvia divinorum',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis), Salvia divinorum, Ketamina, 2cb',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis), Salvia divinorum',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), Marihuana ',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), 2C - B',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Cannabis',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Ibogaína (iboga)',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Kambo',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Ketamina ',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Ketamina, 2CB',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Salvia divinorum, 2cb, ketamina'
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Salvia divinorum, 2CE-embome 2CI-embome ketamina',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Salvia divinorum, Éxtasis, speed,coca',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), Salvia divinorum',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales)',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), Marihuana',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), 2CB, harmal',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), 2cb. Al-lad. Pink star ',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), 2CB',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), 4-HO-MET y 2CB',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), cannabis, mandragora, opio, diclorometano, clonazepam, diazepam, cocaina, telaranas, ketamina, morfina, 2CB, absenta ',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Changa (DMT) y Ketamina',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Éxtasis púrpura ',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Heroína, cocaína,Piper,tussi',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Ipomea , thc , floripondio ',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Ketamina',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Marihuana',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Salvia divinorum, Damiana',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Salvia divinorum, Ketamina ',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Salvia divinorum, Ketamina',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Salvia divinorum, Opio,efedrina',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), Nbome y lsa',
'LSD (ácido, tripi), Tela de araña',
'LSD (ácido, tripi), Tusi', 'LSD (ácido, tripi), Salvia divinorum',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), 4-HO-MET    y  2CB',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Salvia divinorum, 2cb, ketamina',
'LSD (ácido, tripi), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Salvia divinorum, 2CE-embome 2CI-embome ketamina']   
       

psilo = ['Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Salvia divinorum',
       'Psilocibina (setas o trufas mágicas), MDMA (éxtasis)',
       'Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis)',
       'Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Salvia divinorum, Marihuana',
       'Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Ketamina, Popper, Speed',
       'Psilocibina (setas o trufas mágicas)',
       'Psilocibina',
       'Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis), Ibogaína (iboga)',
       'Psilocibina (setas o trufas mágicas), 5 Meo-DMT (bufo alvarius/sapo, sintético)',
       'Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético)',
       'Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Ketamina ',
'Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Salvia divinorum',
'Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), THC, coca, opio, 2cb, datura,',
'Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), Yopo',
'Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales)',
'Psilocibina (setas o trufas mágicas), Marihuana ',
'Psilocibina (setas o trufas mágicas), MDMA (éxtasis), 2cb',
'Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Marihuana, cocaína y éxtasis.',
'Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Salvia divinorum, Ketamina, 4-aco-dmt, 6-apb, cannabis',
'Psilocibina (setas o trufas mágicas), Salvia divinorum',
'PSILOCIBINA MICRODOCIS', 'Marihuana ',
'Hongos',
'Hongos alucinógenos',
'Cucumelos y ketamina']


mescalina = ['Mescalina (peyote, San Pedro/wachuma)',
              'Mescalina (peyote, San Pedro/wachuma), Rape ',
              'Mescalina',
              'Mescalina (peyote, San Pedro/wachuma), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético)',
              'Mescalina (peyote, San Pedro/wachuma), DMT (ayahuasca, en cristales), Marihuana',
              'Mescalina (peyote, San Pedro/wachuma), DMT (ayahuasca, en cristales), MDMA (éxtasis)',
              'Mescalina (peyote, San Pedro/wachuma), DMT (ayahuasca, en cristales), Salvia divinorum',
              'Mescalina (peyote, San Pedro/wachuma), DMT (ayahuasca, en cristales)',
              'Mescalina (peyote, San Pedro/wachuma), MDMA (éxtasis)',
              'Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), MDMA (éxtasis)',
              'Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), Ololiuqui',
              'Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético), Salvia divinorum',
              'Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético)',
              'Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales), MDMA (éxtasis), Ibogaína (iboga)',
              'Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), DMT (ayahuasca, en cristales)',
              'Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), MDMA (éxtasis), Salvia divinorum',
              'Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), MDMA (éxtasis)',
              'Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas), Salvia divinorum',
              'Mescalina (peyote, San Pedro/wachuma), Psilocibina (setas o trufas mágicas)']

extasis = ['MDMA (éxtasis)',
           'MDMA (éxtasis), Ketamina? O no es psicodèlic?',
           'Éxtasis',
           'MDMA (éxtasis), Salvia divinorum',]

ayahuasca_dmt = ['DMT (ayahuasca, en cristales)',
                 'Ninguna, DMT (ayahuasca, en cristales)',
                 'DMT (ayahuasca, en cristales), 5 Meo-DMT (bufo alvarius/sapo, sintético)',
                 'Ayahuasca en Té',
                 'DMT (ayahuasca, en cristales), MDMA (éxtasis)',
                 'Ayahuasca no en cristales']
       
cocaina = 'Cocaina'

marihuana = ['Marihuana',
             'THC, nitrito de amilo', 'Ninguna, Marihuana', 'Metilfenidato ',
             'MARIHUANA',
             'THC',
             'porros',
             'marihuana',]

ninguna = 'Ninguna'


df['sustancias_consumidas_princ'] = df['sustancias_consumidas_princ'].replace(lsd, 'LSD')
df['sustancias_consumidas_princ'] = df['sustancias_consumidas_princ'].replace(psilo, 'Psilocibina')
df['sustancias_consumidas_princ'] = df['sustancias_consumidas_princ'].replace(mescalina, 'Mescalina')
df['sustancias_consumidas_princ'] = df['sustancias_consumidas_princ'].replace(extasis, 'Éxtasis')
df['sustancias_consumidas_princ'] = df['sustancias_consumidas_princ'].replace(ayahuasca_dmt, 'Ayahuasca/DMT')
df['sustancias_consumidas_princ'] = df['sustancias_consumidas_princ'].replace(cocaina, 'Cocaina')
df['sustancias_consumidas_princ'] = df['sustancias_consumidas_princ'].replace(marihuana, 'Marihuana')
bdf['sustancias_consumidas_princ'] = df['sustancias_consumidas_princ'].replace(ninguna, 'Ninguna sustancia')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[874], line 194
#     192 df['sustancias_consumidas_princ'] = df['sustancias_consumidas_princ'].replace(cocaina, 'Cocaina')
#     193 df['sustancias_consumidas_princ'] = df['sustancias_consumidas_princ'].replace(marihuana, 'Marihuana')
# --> 194 bdf['sustancias_consumidas_princ'] = df['sustancias_consumidas_princ'].replace(ninguna, 'Ninguna sustancia')
#
# NameError: name 'bdf' is not defined

# %%
#Reducimos la columna 'motivacion' a solo 6 categorías

diversion = ['Para divertirme, Para conocerme mejor, Con fines terapéuticos, Con fines religiosos o espirituales',
             'Para divertirme, Para escapar de mis problemas',
             'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Con fines religiosos o espirituales, Para potenciar mi creatividad, Para escapar de mis problemas',
              'Para divertirme, Para escapar de mis problemas, Para ser aceptado en el grupo',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Con fines religiosos o espirituales, Para potenciar mi creatividad',
              'Para divertirme, Para conocerme mejor, Para potenciar mi creatividad',
              'Para divertirme, Para conocerme mejor',
              'Para divertirme, Para potenciar mi creatividad',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Para potenciar mi creatividad',
              'Para divertirme, Para ser aceptado en el grupo',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Para potenciar mi creatividad, Para escapar de mis problemas',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Con fines religiosos o espirituales, Para potenciar mi creatividad, Para conectar con la naturaleza, o hacer download de información. Tambien, cuando trabajo con hongos, para preguntarles que necesitan de mi o si estoy en el buen camino',
              'Para divertirme, Con fines terapéuticos',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Con fines religiosos o espirituales, Para escapar de mis problemas, Para ser aceptado en el grupo',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Con fines religiosos o espirituales, Para potenciar mi creatividad, Para escapar de mis problemas, Para ser aceptado en el grupo, No sé',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Con fines religiosos o espirituales, Para potenciar mi creatividad, Para escapar de mis problemas, Para ser aceptado en el grupo',
              'Para divertirme, Para conocerme mejor, Con fines religiosos o espirituales, Para potenciar mi creatividad, Depende de si es microdosis ',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Con fines religiosos o espirituales, Para escapar de mis problemas',
              'Para divertirme, Con fines terapéuticos, Con fines religiosos o espirituales',
              'Para divertirme, Para conocerme mejor, Para escapar de mis problemas',
              'Para divertirme, Con fines religiosos o espirituales, Para escapar de mis problemas',
              'Para divertirme, Para conocerme mejor, Con fines religiosos o espirituales, Para potenciar mi creatividad',
              'Para divertirme, Con fines terapéuticos, Para potenciar mi creatividad',
              'Para divertirme, Para conocerme mejor, Con fines religiosos o espirituales',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Con fines religiosos o espirituales, Para potenciar mi creatividad, Para transformar mis síntomas del capitalismo: ansiedad, strees, desconexión, insomnio...',
              'Para divertirme, Para conocerme mejor, Con fines religiosos o espirituales, Para potenciar mi creatividad, Para escapar de mis problemas',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Para escapar de mis problemas, Para ser aceptado en el grupo',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Para expandir mi conciencia',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Para potenciar mi creatividad, Para ayuda en solucion de problemas y traumas',
              'Para divertirme, Para saber que se siente',
              'Para divertirme, No sé',
              'Para divertirme, Para conocerme mejor, Con fines religiosos o espirituales, Para escapar de mis problemas',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Con fines religiosos o espirituales, Para potenciar mi creatividad, Para hiperdesarrollar mi cerebro y evolucionar',
              'Para divertirme, Para conocerme mejor, Para potenciar mi creatividad, Para ser aceptado en el grupo',
              'Para divertirme, Para potenciar mi creatividad, Incrementa mi capacidad cerebral mi coeficiente intelectual pasó de 97 a 148',
              'Para divertirme, Para potenciar mi creatividad, Para escapar de mis problemas',
              'Para divertirme, Para conocerme mejor, Para potenciar mi creatividad, Para deshabituarme del consumo de tabaco y ',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Para escapar de mis problemas',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Con fines religiosos o espirituales, Para conectar con la tierra y ver / conectar con ella con más profundidad ',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Para desengancharme de la cocaina ',
              'Para divertirme, Para conocerme mejor, Para potenciar mi creatividad, No sé',
              'Para divertirme, Para potenciar mi creatividad, Con la psilocibina en pequeñas dosis es para ser mas consciente de todo tu entorno ',
              'Para divertirme, Para conocerme mejor, Para potenciar mi creatividad, explorar hasta donde llega la capacidad racional del humano',
              'Para divertirme, Para conocerme mejor, Para potenciar mi creatividad, Para escapar de mis problemas, Para ser aceptado en el grupo',
              'Para divertirme, Para relajarme y desestresarme del día a día ',
              'Para divertirme, experimentar',
              'Para divertirme, Para conocerme mejor, Con fines terapéuticos, Con fines religiosos o espirituales, Para potenciar mi creatividad, Connectar con la naturaleza',
              'Para divertirme, Para conocerme mejor, Para buscar y encontrar el sentido de mi mismo y de la existencia',
              'Para divertirme, Para conocerme mejor, Para potenciar mi creatividad, Para escapar de mis problemas',
              'Por gusto y curiosidad de sus efectos. cada vez mas interesantes.',
              'Para divertirme, Con fines religiosos o espirituales',
              'Consumía para divertirme ',
              'Probar experiencia ',
              'Para experimentar',
              'Para divertirme']

conocerse =  ['Para conocerme mejor, Con fines terapéuticos, Con fines religiosos o espirituales, Para potenciar mi creatividad',
              'Para conocerme mejor, Para escapar de mis problemas, Para ser aceptado en el grupo',
              'Para conocerme mejor, Con fines religiosos o espirituales, Probé más que nada porque tenía una inmensa curiosidad y pasión por psicodélicos. ',
              'Para conocerme mejor, Con fines terapéuticos, Con fines religiosos o espirituales, Para escapar de mis problemas',
              'Para conocerme mejor, Para expandir mi conciencia',
              'Para conocerme mejor, Para escapar de mis problemas', 'Descubrir',
              'Para conocerme mejor, Con fines terapéuticos, Con fines religiosos o espirituales, Para potenciar mi creatividad, Para escapar de mis problemas',
              'Para conocerme mejor, Para potenciar mi creatividad, Para escapar de mis problemas',
              'Para conocerme mejor, Con fines terapéuticos, Para entrar en mi subconsciente y conocer que hay ahí que no conozco y para reconocer ese sentimiento y así poder implementarlo en mi realidad.',
              'Para conocerme mejor, Con fines terapéuticos, Para potenciar mi creatividad',
              'Para conocerme mejor, Con fines religiosos o espirituales, Para potenciar mi creatividad',
              'Para conocerme mejor, Con fines religiosos o espirituales',
              'Para conocerme mejor, Con fines terapéuticos, Con fines religiosos o espirituales',
              'Para conocerme mejor',         
              'Para conocerme mejor, Para potenciar mi creatividad',
              'Para conocerme mejor, Con fines terapéuticos, para meditar',
              'Para conocerme mejor, Con fines terapéuticos']

terapeutico = ['Con fines terapéuticos',
              'Con fines terapéuticos, No sé',
              'Con fines terapéuticos, Con fines religiosos o espirituales',
              'Con fines terapéuticos, Para potenciar mi creatividad',
              'relajarme',
              'Para escapar de mis problemas',
              'Soy Asperger y el Cananbis me completa emocionalmente.',
              'Con fines terapéuticos, Trabajo',
              'Me gustaría vivir esa experiencia,  con fines sanadores y espirituales ',
              'Con fines terapéuticos, Con fines religiosos o espirituales, Me gustaría ',
              'Cefalea en racimos ']

creatividad = ['Para potenciar mi creatividad, No sé',
               'Para potenciar mi creatividad',
               'Para potenciar mi creatividad, Para escapar de mis problemas']
       
espiritual = ['Con fines religiosos o espirituales, Para potenciar mi creatividad, No he consumido',
              'una vez sola con fines espirituales',
              'Con fines religiosos o espirituales',
              'Para encontrarme en la unidad, sentirme parte del universo, y comprender sus mensajes',
              'Para específicamente encontrar una respuesta ',
              'Con fines religiosos o espirituales, Para potenciar mi creatividad']

otros = ['No sé, Experimental.',
         'No sabía que era una sustancia psicodélica hasta que la probé',
         'No consumo, las consumi sin saber',
         'No he consumido, Intrigado por los posibles efectos.',
         'Sexo',
         'Interes en las drogas sicodelicas y su conocimiento',
         'Para obtener la sabiduría que la medicina da, y entrar en ese maravilloso  reino.',
         'No sé',
         'No he consumido']

# %%
df['motivacion_princ'] = df['motivacion_princ'].replace(diversion, 'Diversión')
df['motivacion_princ'] = df['motivacion_princ'].replace(conocerse, 'Conocerse')
df['motivacion_princ'] = df['motivacion_princ'].replace(terapeutico, 'Terapeutico')
df['motivacion_princ'] = df['motivacion_princ'].replace(creatividad, 'Creatividad')
df['motivacion_princ'] = df['motivacion_princ'].replace(espiritual, 'Educación')
df['motivacion_princ'] = df['motivacion_princ'].replace(otros, 'Otra motivación')
